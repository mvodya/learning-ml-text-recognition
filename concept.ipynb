# %%
pip install opencv-python idx2numpy
# Out:
# Collecting opencv-python
#   Downloading opencv_python-4.10.0.84-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (20 kB)
# Collecting idx2numpy
#   Downloading idx2numpy-1.2.3.tar.gz (6.8 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: numpy>=1.21.2 in /opt/conda/lib/python3.12/site-packages (from opencv-python) (1.26.4)
# Requirement already satisfied: six in /opt/conda/lib/python3.12/site-packages (from idx2numpy) (1.16.0)
# Downloading opencv_python-4.10.0.84-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (62.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.5/62.5 MB 3.5 MB/s eta 0:00:0000:0100:010m
# Building wheels for collected packages: idx2numpy
#   Building wheel for idx2numpy (setup.py) ... done
#   Created wheel for idx2numpy: filename=idx2numpy-1.2.3-py3-none-any.whl size=7904 sha256=007f0a75493488ea8250883a404ce1db5fb88ec51019a7196e7d00464c5412a7
#   Stored in directory: /home/jovyan/.cache/pip/wheels/f7/48/00/ae031c97d62f39e1c3c4daa00426c09a65eb29ae5753a189ee
# Successfully built idx2numpy
# Installing collected packages: opencv-python, idx2numpy
# Successfully installed idx2numpy-1.2.3 opencv-python-4.10.0.84
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np
from matplotlib import pyplot as plt
import cv2
from PIL import Image
from IPython.display import display
import idx2numpy
import gzip
import numpy as np

# %%
img = cv2.imread("text-hand.png")
display(Image.fromarray(img))

# Переводим картинку в ч/б (и так была ч/б)
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
# Бинаризация изображения с помощью метода пороговой обработки
ret, img_thresh = cv2.threshold(gray, 20, 255, cv2.THRESH_BINARY)
# Эрозия на бинарном изображении
img_erode = cv2.erode(img_thresh, np.ones((3, 3), np.uint8), iterations=2)

display(Image.fromarray(img_erode))
# Out:
# <PIL.Image.Image image mode=RGB size=860x227>
# <PIL.Image.Image image mode=L size=860x227>

# %%
# Открываем изображение
img = cv2.imread("text-hand.png")

fig, axs = plt.subplots(1, 3, layout='constrained', figsize=(10, 3))
axs[0].imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
axs[0].set_axis_off()
axs[0].set_title("Оригинальное изображение")

# Переводим картинку в ч/б (и так была ч/б)
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
# Бинаризация изображения с помощью метода пороговой обработки
ret, img_thresh = cv2.threshold(gray, 20, 255, cv2.THRESH_BINARY)

axs[1].imshow(cv2.cvtColor(img_thresh, cv2.COLOR_BGR2RGB))
axs[1].set_axis_off()
axs[1].set_title("Бинаризация")

# Эрозия на бинарном изображении
img_erode = cv2.erode(img_thresh, np.ones((3, 3), np.uint8), iterations=2)

axs[2].imshow(cv2.cvtColor(img_erode, cv2.COLOR_BGR2RGB))
axs[2].set_axis_off()
axs[2].set_title("Эрозия")

plt.show()

# %%
# Нахождение контуров
contours, hierarchy = cv2.findContours(img_erode, cv2.RETR_TREE, cv2.CHAIN_APPROX_NONE)

output = img.copy()

# Рисуем прямоугольники вокруг контуров
for idx, contour in enumerate(contours):
    (x, y, w, h) = cv2.boundingRect(contour)
    if hierarchy[0][idx][3] == 0:  # Если контур не имеет родительских контуров
        # Рисуем прямоугольник в виде бокса
        cv2.rectangle(output, (x, y), (x + w, y + h), (255, 0, 0), 2)

display(Image.fromarray(output))
# Out:
# <PIL.Image.Image image mode=RGB size=860x227>

# %%
# Нахождение контуров
contours, hierarchy = cv2.findContours(img_erode, cv2.RETR_TREE, cv2.CHAIN_APPROX_NONE)

fig, ax = plt.subplots(figsize=(7, 7))
ax.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))

# Для каждого контура рисуем его bounding box
for idx, contour in enumerate(contours):
    (x, y, w, h) = cv2.boundingRect(contour)
    if hierarchy[0][idx][3] == 0:  # Если контур не имеет родительских контуров
        # Рисуем прямоугольник в виде бокса
        rect = plt.Rectangle((x, y), w, h, linewidth=2, edgecolor='r', facecolor='none')
        ax.add_patch(rect)

ax.set_axis_off()
ax.set_title("Контуры")
plt.show()

# %%
def letters_extract(image_file: str, out_size=28):
    # Чтение изображения
    img = cv2.imread(image_file)

    # Преобразование изображения в градации серого
    gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    # Бинаризация изображения
    ret, thresh = cv2.threshold(gray, 20, 255, cv2.THRESH_BINARY)
    # Эрозия изображения для улучшения контуров
    img_erode = cv2.erode(thresh, np.ones((3, 3), np.uint8), iterations=1)

    # Получение контуров
    contours, hierarchy = cv2.findContours(img_erode, cv2.RETR_TREE, cv2.CHAIN_APPROX_NONE)
    output = img.copy()

    # Список для сохранения букв
    letters = []

    # Перебираем контуры
    for idx, contour in enumerate(contours):
        # Получение ограничивающего прямоугольника для контура
        (x, y, w, h) = cv2.boundingRect(contour)

        # Проверка, что контур не вложен в другой контур
        if hierarchy[0][idx][3] == 0:
            # Вырезаем букву
            letter_crop = gray[y:y + h, x:x + w]

            # Приведение буквы к квадрату
            size_max = max(w, h)
            letter_square = 255 * np.ones(shape=[size_max, size_max], dtype=np.uint8)

            if w > h:
                # Увеличение изображения по вертикали
                y_pos = size_max // 2 - h // 2
                letter_square[y_pos:y_pos + h, 0:w] = letter_crop
            elif w < h:
                # Увеличение изображения по горизонтали
                x_pos = size_max // 2 - w // 2
                letter_square[0:h, x_pos:x_pos + w] = letter_crop
            else:
                letter_square = letter_crop

            # Изменение размера буквы и добавление в список
            letters.append((x, w, cv2.resize(letter_square, (out_size, out_size), interpolation=cv2.INTER_AREA)))

    # Сортировка букв по координате X (чтобы располагать их слева направо)
    letters.sort(key=lambda x: x[0], reverse=False)

    return letters

letters=letters_extract('text-hand.png')
display(Image.fromarray(letters[0][2]))
display(Image.fromarray(letters[1][2]))
display(Image.fromarray(letters[2][2]))
display(Image.fromarray(letters[3][2]))
display(Image.fromarray(letters[4][2]))
display(Image.fromarray(letters[5][2]))
# Out:
# <PIL.Image.Image image mode=L size=28x28>
# <PIL.Image.Image image mode=L size=28x28>
# <PIL.Image.Image image mode=L size=28x28>
# <PIL.Image.Image image mode=L size=28x28>
# <PIL.Image.Image image mode=L size=28x28>
# <PIL.Image.Image image mode=L size=28x28>

# %%
from tensorflow import keras
from keras.models import Sequential
from keras import optimizers
from keras.layers import Convolution2D, MaxPooling2D, Dropout, Flatten, Dense, Reshape, LSTM, BatchNormalization
from keras.optimizers import SGD, RMSprop, Adam
from keras import backend as K
from keras.constraints import max_norm
import tensorflow as tf
from tensorflow.keras.callbacks import ModelCheckpoint
from sklearn.model_selection import KFold
# Out:
# 2024-10-24 07:13:21.793063: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-10-24 07:13:21.925504: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-10-24 07:13:21.962106: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-10-24 07:13:22.237908: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-10-24 07:13:23.613245: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
# EMNIST (Extended MNIST)
def emnist_model():
    # Инициализация модели
    model = Sequential()

    # Первый сверточный слой с 32 фильтрами, размером ядра (3, 3), активация ReLU
    model.add(Convolution2D(filters=32, kernel_size=(3, 3), padding='valid', input_shape=(28, 28, 1), activation='relu'))

    # Второй сверточный слой с 64 фильтрами, активация ReLU
    model.add(Convolution2D(filters=64, kernel_size=(3, 3), activation='relu'))

    # Слой подвыборки (MaxPooling) с размером окна (2, 2)
    model.add(MaxPooling2D(pool_size=(2, 2)))

    # Слой Dropout для предотвращения переобучения (25% нейронов отключаются случайным образом)
    model.add(Dropout(0.25))

    # Преобразование двумерных данных в одномерный вектор
    model.add(Flatten())

    # Полносвязный слой с 512 нейронами, активация ReLU
    model.add(Dense(512, activation='relu'))

    # Слой Dropout для предотвращения переобучения (50% нейронов отключаются случайным образом)
    model.add(Dropout(0.5))

    # Выходной полносвязный слой, количество нейронов соответствует числу классов (emnist_labels), активация softmax
    model.add(Dense(len(emnist_labels), activation='softmax'))

    # Компиляция модели с функцией потерь 'categorical_crossentropy', оптимизатором 'adadelta' и метрикой 'accuracy'
    model.compile(loss='categorical_crossentropy', optimizer='adadelta', metrics=['accuracy'])

    return model

# %%
# Путь к набору данных EMNIST
emnist_path = 'dataset/'

# Функция для исправления поворота и зеркального отображения
def correct_image_orientation(images):
    corrected_images = []
    for img in images:
        # Поворот изображения на 90 градусов против часовой стрелки
        rotated_img = cv2.rotate(img, cv2.ROTATE_90_COUNTERCLOCKWISE)
        # Отзеркаливание по вертикали
        corrected_img = cv2.flip(rotated_img, 0)
        # Инверсия цветов (фон становится белым, а текст — чёрным)
        inverted_img = 255 - corrected_img
        corrected_images.append(inverted_img)
    return np.array(corrected_images)

# Загрузка тренировочных изображений и меток с использованием idx2numpy
with gzip.open(emnist_path + 'emnist-byclass-train-images-idx3-ubyte.gz', 'rb') as f:
    X_train = idx2numpy.convert_from_file(f)
with gzip.open(emnist_path + 'emnist-byclass-train-labels-idx1-ubyte.gz', 'rb') as f:
    y_train = idx2numpy.convert_from_file(f)

# Загрузка тестовых изображений и меток
with gzip.open(emnist_path + 'emnist-byclass-test-images-idx3-ubyte.gz', 'rb') as f:
    X_test = idx2numpy.convert_from_file(f)
with gzip.open(emnist_path + 'emnist-byclass-test-labels-idx1-ubyte.gz', 'rb') as f:
    y_test = idx2numpy.convert_from_file(f)

# Применение исправлений к тренировочным и тестовым изображениям
X_train = correct_image_orientation(X_train)
X_test = correct_image_orientation(X_test)

# Преобразование изображений в форму (количество, 28, 28, 1) для использования в модели
X_train = np.reshape(X_train, (X_train.shape[0], 28, 28, 1))
X_test = np.reshape(X_test, (X_test.shape[0], 28, 28, 1))

# Чтение файла и создание отображения индексов на символы
emnist_labels = {}
with open(emnist_path + 'emnist-byclass-mapping.txt', 'r') as f:
    for line in f:
        index, ascii_code = line.split()
        emnist_labels[int(index)] = chr(int(ascii_code))  # Преобразование ASCII-кода в символ

# Проверка размеров данных
print(X_train.shape, y_train.shape, X_test.shape, y_test.shape, len(emnist_labels))

# Уменьшение размера набора данных для ускорения обучения (в 5 раз)
# k = 5
k = 3
X_train = X_train[:X_train.shape[0] // k]
y_train = y_train[:y_train.shape[0] // k]
X_test = X_test[:X_test.shape[0] // k]
y_test = y_test[:y_test.shape[0] // k]

# Нормализация изображений к диапазону [0, 1]
X_train = X_train.astype(np.float32) / 255.0
X_test = X_test.astype(np.float32) / 255.0

# Преобразование меток в категориальный формат (one-hot encoding)
y_train_cat = keras.utils.to_categorical(y_train, len(emnist_labels))
y_test_cat = keras.utils.to_categorical(y_test, len(emnist_labels))

# Вывод данных после преобразований для проверки
print(f"Тренировочные данные: {X_train.shape}, Метки: {y_train_cat.shape}")
print(f"Тестовые данные: {X_test.shape}, Метки: {y_test_cat.shape}")
# Out:
# (697932, 28, 28, 1) (697932,) (116323, 28, 28, 1) (116323,) 62
# Тренировочные данные: (232644, 28, 28, 1), Метки: (232644, 62)
# Тестовые данные: (38774, 28, 28, 1), Метки: (38774, 62)

# %%
def plot_samples_with_ax(X_data, y_data, title, emnist_labels, num_samples=5):
    fig, axs = plt.subplots(1, num_samples, figsize=(12, 2))

    for i in range(num_samples):
        # Отображаем изображение на соответствующем ax
        axs[i].imshow(X_data[i].reshape(28, 28), cmap='gray')
        # Устанавливаем заголовок для каждого изображения
        axs[i].set_title(f"Label: {emnist_labels[np.argmax(y_data[i])]}")
        # Отключаем оси
        axs[i].axis('off')

    # Устанавливаем заголовок для всей фигуры
    fig.suptitle(title)
    fig.tight_layout()
    plt.show()

# Отображаем 12 тренировочных изображений
plot_samples_with_ax(X_train, y_train_cat, "Тренировочные данные", emnist_labels, num_samples=12)

# Отображаем 12 тестовых изображений
plot_samples_with_ax(X_test, y_test_cat, "Тестовые данные", emnist_labels, num_samples=12)

# %%
# Определение модели
model = emnist_model()

# Добавляем чекпоинты для сохранения лучших весов
checkpoint = ModelCheckpoint('best_model.keras', monitor='val_accuracy', save_best_only=True, mode='max', verbose=1)

# Обучение модели
history = model.fit(
    X_train, y_train_cat,                 # Тренировочные данные и метки
    batch_size=128,                       # Размер батча
    epochs=50,                            # Количество эпох
    validation_data=(X_test, y_test_cat), # Валидационные данные
    callbacks=[checkpoint],               # Используем чекпоинты
    verbose=1                             # Отображение процесса обучения
)

# Загрузка лучших весов после обучения
model.load_weights('best_model.keras')

# Оценка модели на тестовых данных
test_loss, test_acc = model.evaluate(X_test, y_test_cat, verbose=2)
print(f'Точность на тестовых данных: {test_acc * 100:.2f}%')
# Out:
# Epoch 1/50
# 1818/1818 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.0407 - loss: 4.0043
# Epoch 1: val_accuracy improved from -inf to 0.09034, saving model to best_model.keras
# 1818/1818 ━━━━━━━━━━━━━━━━━━━━ 10s 4ms/step - accuracy: 0.0407 - loss: 4.0042 - val_accuracy: 0.0903 - val_loss: 3.6682
# Epoch 2/50
# 1817/1818 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.0782 - loss: 3.7083
# Epoch 2: val_accuracy improved from 0.09034 to 0.23041, saving model to best_model.keras
# 1818/1818 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.0782 - loss: 3.7083 - val_accuracy: 0.2304 - val_loss: 3.5489
# Epoch 3/50
# 1815/1818 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.1171 - loss: 3.6124
# Epoch 3: val_accuracy improved from 0.23041 to 0.32504, saving model to best_model.keras
# 1818/1818 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.1171 - loss: 3.6123 - val_accuracy: 0.3250 - val_loss: 3.4086
# Epoch 4/50
# 1814/1818 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.1778 - loss: 3.4746
# Epoch 4: val_accuracy improved from 0.32504 to 0.37927, saving model to best_model.keras
# 1818/1818 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.1779 - loss: 3.4745 - val_accuracy: 0.3793 - val_loss: 3.2018
# Epoch 5/50
# 1812/1818 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.2465 - loss: 3.2767
# Epoch 5: val_accuracy improved from 0.37927 to 0.41554, saving model to best_model.keras
# 1818/1818 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.2466 - loss: 3.2765 - val_accuracy: 0.4155 - val_loss: 2.9375
# Epoch 6/50
# 1808/1818 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.3135 - loss: 3.0399
# Epoch 6: val_accuracy improved from 0.41554 to 0.44576, saving model to best_model.keras
# 1818/1818 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.3135 - loss: 3.0395 - val_accuracy: 0.4458 - val_loss: 2.6491
# Epoch 7/50
# 1800/1818 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.3631 - loss: 2.8002
# Epoch 7: val_accuracy improved from 0.44576 to 0.47026, saving model to best_model.keras
# 1818/1818 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.3632 - loss: 2.7996 - val_accuracy: 0.4703 - val_loss: 2.3981
# Epoch 8/50
# 1813/1818 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.3998 - loss: 2.5905
# Epoch 8: val_accuracy improved from 0.47026 to 0.49466, saving model to best_model.keras
# 1818/1818 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.3998 - loss: 2.5904 - val_accuracy: 0.4947 - val_loss: 2.2090
# Epoch 9/50
# 1805/1818 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4290 - loss: 2.4352
# Epoch 9: val_accuracy improved from 0.49466 to 0.51648, saving model to best_model.keras
# 1818/1818 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.4290 - loss: 2.4350 - val_accuracy: 0.5165 - val_loss: 2.0643
# Epoch 10/50
# 1810/1818 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.4463 - loss: 2.3184
# Epoch 10: val_accuracy improved from 0.51648 to 0.53538, saving model to best_model.keras
# 1818/1818 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.4463 - loss: 2.3182 - val_accuracy: 0.5354 - val_loss: 1.9542
# Epoch 11/50
# 1813/1818 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.4660 - loss: 2.2179
# Epoch 11: val_accuracy improved from 0.53538 to 0.55395, saving model to best_model.keras
# 1818/1818 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.4660 - loss: 2.2178 - val_accuracy: 0.5540 - val_loss: 1.8630
# Epoch 12/50
# 1814/1818 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.4816 - loss: 2.1312
# Epoch 12: val_accuracy improved from 0.55395 to 0.56765, saving model to best_model.keras
# 1818/1818 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.4816 - loss: 2.1311 - val_accuracy: 0.5676 - val_loss: 1.7896
# Epoch 13/50
# 1814/1818 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.4965 - loss: 2.0554
# Epoch 13: val_accuracy improved from 0.56765 to 0.58127, saving model to best_model.keras
# 1818/1818 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.4965 - loss: 2.0553 - val_accuracy: 0.5813 - val_loss: 1.7234
# Epoch 14/50
# 1803/1818 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5121 - loss: 1.9896
# Epoch 14: val_accuracy improved from 0.58127 to 0.59254, saving model to best_model.keras
# 1818/1818 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.5121 - loss: 1.9895 - val_accuracy: 0.5925 - val_loss: 1.6662
# Epoch 15/50
# 1800/1818 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5190 - loss: 1.9337
# Epoch 15: val_accuracy improved from 0.59254 to 0.60066, saving model to best_model.keras
# 1818/1818 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.5191 - loss: 1.9335 - val_accuracy: 0.6007 - val_loss: 1.6153
# Epoch 16/50
# 1815/1818 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5298 - loss: 1.8771
# Epoch 16: val_accuracy improved from 0.60066 to 0.60964, saving model to best_model.keras
# 1818/1818 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.5298 - loss: 1.8771 - val_accuracy: 0.6096 - val_loss: 1.5680
# Epoch 17/50
# 1806/1818 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5390 - loss: 1.8326
# Epoch 17: val_accuracy improved from 0.60964 to 0.61709, saving model to best_model.keras
# 1818/1818 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.5390 - loss: 1.8325 - val_accuracy: 0.6171 - val_loss: 1.5265
# Epoch 18/50
# 1808/1818 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5485 - loss: 1.7865
# Epoch 18: val_accuracy improved from 0.61709 to 0.62452, saving model to best_model.keras
# 1818/1818 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.5485 - loss: 1.7864 - val_accuracy: 0.6245 - val_loss: 1.4859
# Epoch 19/50
# 1803/1818 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5557 - loss: 1.7512
# Epoch 19: val_accuracy improved from 0.62452 to 0.62872, saving model to best_model.keras
# 1818/1818 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.5557 - loss: 1.7511 - val_accuracy: 0.6287 - val_loss: 1.4505
# Epoch 20/50
# 1802/1818 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5624 - loss: 1.7137
# Epoch 20: val_accuracy improved from 0.62872 to 0.63478, saving model to best_model.keras
# 1818/1818 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.5624 - loss: 1.7136 - val_accuracy: 0.6348 - val_loss: 1.4166
# Epoch 21/50
# 1796/1818 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5705 - loss: 1.6672
# Epoch 21: val_accuracy improved from 0.63478 to 0.64076, saving model to best_model.keras
# 1818/1818 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.5705 - loss: 1.6672 - val_accuracy: 0.6408 - val_loss: 1.3856
# Epoch 22/50
# 1806/1818 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5752 - loss: 1.6372
# Epoch 22: val_accuracy improved from 0.64076 to 0.64590, saving model to best_model.keras
# 1818/1818 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.5752 - loss: 1.6372 - val_accuracy: 0.6459 - val_loss: 1.3570
# Epoch 23/50
# 1803/1818 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5791 - loss: 1.6175
# Epoch 23: val_accuracy improved from 0.64590 to 0.64964, saving model to best_model.keras
# 1818/1818 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.5791 - loss: 1.6174 - val_accuracy: 0.6496 - val_loss: 1.3297
# Epoch 24/50
# 1814/1818 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5846 - loss: 1.5856
# Epoch 24: val_accuracy improved from 0.64964 to 0.65505, saving model to best_model.keras
# 1818/1818 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.5846 - loss: 1.5856 - val_accuracy: 0.6551 - val_loss: 1.3038
# Epoch 25/50
# 1798/1818 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5897 - loss: 1.5568
# Epoch 25: val_accuracy improved from 0.65505 to 0.65982, saving model to best_model.keras
# 1818/1818 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.5897 - loss: 1.5568 - val_accuracy: 0.6598 - val_loss: 1.2810
# Epoch 26/50
# 1804/1818 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5958 - loss: 1.5323
# Epoch 26: val_accuracy improved from 0.65982 to 0.66441, saving model to best_model.keras
# 1818/1818 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.5958 - loss: 1.5322 - val_accuracy: 0.6644 - val_loss: 1.2573
# Epoch 27/50
# 1814/1818 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5986 - loss: 1.5123
# Epoch 27: val_accuracy improved from 0.66441 to 0.66715, saving model to best_model.keras
# 1818/1818 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - accuracy: 0.5986 - loss: 1.5122 - val_accuracy: 0.6671 - val_loss: 1.2367
# Epoch 28/50
# 1811/1818 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6047 - loss: 1.4856
# Epoch 28: val_accuracy improved from 0.66715 to 0.67135, saving model to best_model.keras
# 1818/1818 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.6048 - loss: 1.4855 - val_accuracy: 0.6714 - val_loss: 1.2160
# Epoch 29/50
# 1808/1818 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6101 - loss: 1.4621
# Epoch 29: val_accuracy improved from 0.67135 to 0.67628, saving model to best_model.keras
# 1818/1818 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.6101 - loss: 1.4621 - val_accuracy: 0.6763 - val_loss: 1.1967
# Epoch 30/50
# 1817/1818 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6139 - loss: 1.4424
# Epoch 30: val_accuracy improved from 0.67628 to 0.67883, saving model to best_model.keras
# 1818/1818 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.6139 - loss: 1.4424 - val_accuracy: 0.6788 - val_loss: 1.1791
# Epoch 31/50
# 1807/1818 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6167 - loss: 1.4239
# Epoch 31: val_accuracy improved from 0.67883 to 0.68337, saving model to best_model.keras
# 1818/1818 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.6168 - loss: 1.4238 - val_accuracy: 0.6834 - val_loss: 1.1610
# Epoch 32/50
# 1814/1818 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6221 - loss: 1.4012
# Epoch 32: val_accuracy improved from 0.68337 to 0.68657, saving model to best_model.keras
# 1818/1818 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.6221 - loss: 1.4012 - val_accuracy: 0.6866 - val_loss: 1.1439
# Epoch 33/50
# 1814/1818 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6233 - loss: 1.3868
# Epoch 33: val_accuracy improved from 0.68657 to 0.68941, saving model to best_model.keras
# 1818/1818 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - accuracy: 0.6233 - loss: 1.3867 - val_accuracy: 0.6894 - val_loss: 1.1282
# Epoch 34/50
# 1807/1818 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6274 - loss: 1.3702
# Epoch 34: val_accuracy improved from 0.68941 to 0.69299, saving model to best_model.keras
# 1818/1818 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.6274 - loss: 1.3702 - val_accuracy: 0.6930 - val_loss: 1.1138
# Epoch 35/50
# 1815/1818 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6311 - loss: 1.3511
# Epoch 35: val_accuracy improved from 0.69299 to 0.69559, saving model to best_model.keras
# 1818/1818 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.6311 - loss: 1.3511 - val_accuracy: 0.6956 - val_loss: 1.0996
# Epoch 36/50
# 1812/1818 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6331 - loss: 1.3354
# Epoch 36: val_accuracy improved from 0.69559 to 0.69835, saving model to best_model.keras
# 1818/1818 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.6331 - loss: 1.3354 - val_accuracy: 0.6984 - val_loss: 1.0860
# Epoch 37/50
# 1816/1818 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6365 - loss: 1.3234
# Epoch 37: val_accuracy improved from 0.69835 to 0.70106, saving model to best_model.keras
# 1818/1818 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.6365 - loss: 1.3233 - val_accuracy: 0.7011 - val_loss: 1.0738
# Epoch 38/50
# 1812/1818 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6409 - loss: 1.3062
# Epoch 38: val_accuracy improved from 0.70106 to 0.70398, saving model to best_model.keras
# 1818/1818 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.6409 - loss: 1.3062 - val_accuracy: 0.7040 - val_loss: 1.0598
# Epoch 39/50
# 1802/1818 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6418 - loss: 1.2910
# Epoch 39: val_accuracy improved from 0.70398 to 0.70658, saving model to best_model.keras
# 1818/1818 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - accuracy: 0.6418 - loss: 1.2910 - val_accuracy: 0.7066 - val_loss: 1.0481
# Epoch 40/50
# 1809/1818 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6466 - loss: 1.2783
# Epoch 40: val_accuracy improved from 0.70658 to 0.70934, saving model to best_model.keras
# 1818/1818 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.6466 - loss: 1.2783 - val_accuracy: 0.7093 - val_loss: 1.0360
# Epoch 41/50
# 1808/1818 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6515 - loss: 1.2656
# Epoch 41: val_accuracy improved from 0.70934 to 0.71223, saving model to best_model.keras
# 1818/1818 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.6515 - loss: 1.2656 - val_accuracy: 0.7122 - val_loss: 1.0241
# Epoch 42/50
# 1803/1818 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6539 - loss: 1.2525
# Epoch 42: val_accuracy improved from 0.71223 to 0.71339, saving model to best_model.keras
# 1818/1818 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.6539 - loss: 1.2525 - val_accuracy: 0.7134 - val_loss: 1.0138
# Epoch 43/50
# 1806/1818 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6553 - loss: 1.2428
# Epoch 43: val_accuracy improved from 0.71339 to 0.71633, saving model to best_model.keras
# 1818/1818 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.6553 - loss: 1.2428 - val_accuracy: 0.7163 - val_loss: 1.0038
# Epoch 44/50
# 1800/1818 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6596 - loss: 1.2243
# Epoch 44: val_accuracy improved from 0.71633 to 0.71814, saving model to best_model.keras
# 1818/1818 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.6596 - loss: 1.2243 - val_accuracy: 0.7181 - val_loss: 0.9929
# Epoch 45/50
# 1805/1818 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6597 - loss: 1.2174
# Epoch 45: val_accuracy improved from 0.71814 to 0.72059, saving model to best_model.keras
# 1818/1818 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - accuracy: 0.6597 - loss: 1.2174 - val_accuracy: 0.7206 - val_loss: 0.9834
# Epoch 46/50
# 1814/1818 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6622 - loss: 1.2055
# Epoch 46: val_accuracy improved from 0.72059 to 0.72301, saving model to best_model.keras
# 1818/1818 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.6622 - loss: 1.2055 - val_accuracy: 0.7230 - val_loss: 0.9743
# Epoch 47/50
# 1808/1818 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6652 - loss: 1.1997
# Epoch 47: val_accuracy improved from 0.72301 to 0.72520, saving model to best_model.keras
# 1818/1818 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.6652 - loss: 1.1996 - val_accuracy: 0.7252 - val_loss: 0.9648
# Epoch 48/50
# 1809/1818 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6686 - loss: 1.1833
# Epoch 48: val_accuracy improved from 0.72520 to 0.72776, saving model to best_model.keras
# 1818/1818 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.6686 - loss: 1.1833 - val_accuracy: 0.7278 - val_loss: 0.9555
# Epoch 49/50
# 1818/1818 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6695 - loss: 1.1744
# Epoch 49: val_accuracy improved from 0.72776 to 0.72987, saving model to best_model.keras
# 1818/1818 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.6695 - loss: 1.1744 - val_accuracy: 0.7299 - val_loss: 0.9472
# Epoch 50/50
# 1809/1818 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6709 - loss: 1.1682
# Epoch 50: val_accuracy improved from 0.72987 to 0.73150, saving model to best_model.keras
# 1818/1818 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.6709 - loss: 1.1681 - val_accuracy: 0.7315 - val_loss: 0.9391
# 1212/1212 - 2s - 2ms/step - accuracy: 0.7315 - loss: 0.9391
# Точность на тестовых данных: 73.15%

# %%
# Количество фолдов для кросс-валидации
n_folds = 5
kfold = KFold(n_splits=n_folds, shuffle=True)

# Списки для сохранения результатов
fold_accuracies = []

# Обучение модели с использованием кросс-валидации
for fold_idx, (train_idx, val_idx) in enumerate(kfold.split(X_train, y_train_cat)):
    print(f"Обучение на фолде {fold_idx + 1}/{n_folds}")
    
    # Создаем модель для каждого фолда
    model = emnist_model()
    
    # Получаем данные для текущего фолда
    X_train_fold, X_val_fold = X_train[train_idx], X_train[val_idx]
    y_train_fold, y_val_fold = y_train_cat[train_idx], y_train_cat[val_idx]

    # Обучение модели на текущем фолде
    history = model.fit(
        X_train_fold, y_train_fold,                # Тренировочные данные для текущего фолда
        batch_size=128,                            # Размер батча
        epochs=10,                                 # Количество эпох
        validation_data=(X_val_fold, y_val_fold),  # Валидационные данные для текущего фолда
        verbose=1                                  # Отображение процесса обучения
    )

    # Оценка модели на валидационных данных текущего фолда
    val_loss, val_acc = model.evaluate(X_val_fold, y_val_fold, verbose=0)
    fold_accuracies.append(val_acc)
    print(f"Точность на фолде {fold_idx + 1}: {val_acc * 100:.2f}%")

# Средняя точность по всем фолдам
mean_accuracy = np.mean(fold_accuracies)
print(f'Средняя точность по {n_folds} фолдам: {mean_accuracy * 100:.2f}%')
# Out:
# Обучение на фолде 1/5
# Epoch 1/10
# 1455/1455 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.0459 - loss: 4.0074
# 2024-10-24 07:22:48.256266: I external/local_xla/xla/stream_executor/cuda/cuda_asm_compiler.cc:393] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_72', 44 bytes spill stores, 44 bytes spill loads
# 1455/1455 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - accuracy: 0.0459 - loss: 4.0073 - val_accuracy: 0.1100 - val_loss: 3.6906
# Epoch 2/10
# 1455/1455 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.0764 - loss: 3.7311 - val_accuracy: 0.2165 - val_loss: 3.5823
# Epoch 3/10
# 1455/1455 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.1014 - loss: 3.6486 - val_accuracy: 0.2869 - val_loss: 3.4833
# Epoch 4/10
# 1455/1455 ━━━━━━━━━━━━━━━━━━━━ -75s -51478us/step - accuracy: 0.1415 - loss: 3.5603 - val_accuracy: 0.3538 - val_loss: 3.3541
# Epoch 5/10
# 1455/1455 ━━━━━━━━━━━━━━━━━━━━ 82s 56ms/step - accuracy: 0.1959 - loss: 3.4331 - val_accuracy: 0.3887 - val_loss: 3.1900
# Epoch 6/10
# 1455/1455 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.2491 - loss: 3.2885 - val_accuracy: 0.4191 - val_loss: 2.9913
# Epoch 7/10
# 1455/1455 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.3009 - loss: 3.1072 - val_accuracy: 0.4392 - val_loss: 2.7793
# Epoch 8/10
# 1455/1455 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.3392 - loss: 2.9292 - val_accuracy: 0.4607 - val_loss: 2.5716
# Epoch 9/10
# 1455/1455 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.3710 - loss: 2.7607 - val_accuracy: 0.4764 - val_loss: 2.3913
# Epoch 10/10
# 1455/1455 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.4000 - loss: 2.6108 - val_accuracy: 0.4917 - val_loss: 2.2426
# Точность на фолде 1: 49.17%
# Обучение на фолде 2/5
# Epoch 1/10
# 1455/1455 ━━━━━━━━━━━━━━━━━━━━ -70s -49703us/step - accuracy: 0.0444 - loss: 4.0307 - val_accuracy: 0.1301 - val_loss: 3.6950
# Epoch 2/10
# 1455/1455 ━━━━━━━━━━━━━━━━━━━━ 82s 56ms/step - accuracy: 0.0848 - loss: 3.7233 - val_accuracy: 0.2351 - val_loss: 3.5537
# Epoch 3/10
# 1455/1455 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.1234 - loss: 3.6190 - val_accuracy: 0.3189 - val_loss: 3.4207
# Epoch 4/10
# 1455/1455 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.1746 - loss: 3.4940 - val_accuracy: 0.3705 - val_loss: 3.2502
# Epoch 5/10
# 1455/1455 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.2351 - loss: 3.3371 - val_accuracy: 0.4045 - val_loss: 3.0348
# Epoch 6/10
# 1455/1455 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.2923 - loss: 3.1405 - val_accuracy: 0.4257 - val_loss: 2.7924
# Epoch 7/10
# 1455/1455 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.3436 - loss: 2.9248 - val_accuracy: 0.4515 - val_loss: 2.5633
# Epoch 8/10
# 1455/1455 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.3820 - loss: 2.7344 - val_accuracy: 0.4684 - val_loss: 2.3698
# Epoch 9/10
# 1455/1455 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.4069 - loss: 2.5748 - val_accuracy: 0.4875 - val_loss: 2.2124
# Epoch 10/10
# 1455/1455 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.4277 - loss: 2.4435 - val_accuracy: 0.5070 - val_loss: 2.0874
# Точность на фолде 2: 50.70%
# Обучение на фолде 3/5
# Epoch 1/10
# 1455/1455 ━━━━━━━━━━━━━━━━━━━━ 10s 4ms/step - accuracy: 0.0353 - loss: 4.0523 - val_accuracy: 0.1268 - val_loss: 3.7430
# Epoch 2/10
# 1455/1455 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.0730 - loss: 3.7524 - val_accuracy: 0.2181 - val_loss: 3.6210
# Epoch 3/10
# 1455/1455 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.0986 - loss: 3.6767 - val_accuracy: 0.2810 - val_loss: 3.5300
# Epoch 4/10
# 1455/1455 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.1339 - loss: 3.5922 - val_accuracy: 0.3302 - val_loss: 3.4159
# Epoch 5/10
# 1455/1455 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.1815 - loss: 3.4846 - val_accuracy: 0.3619 - val_loss: 3.2713
# Epoch 6/10
# 1455/1455 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.2328 - loss: 3.3481 - val_accuracy: 0.3897 - val_loss: 3.0883
# Epoch 7/10
# 1455/1455 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.2802 - loss: 3.1891 - val_accuracy: 0.4127 - val_loss: 2.8835
# Epoch 8/10
# 1455/1455 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.3235 - loss: 3.0123 - val_accuracy: 0.4347 - val_loss: 2.6778
# Epoch 9/10
# 1455/1455 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.3587 - loss: 2.8385 - val_accuracy: 0.4553 - val_loss: 2.4899
# Epoch 10/10
# 1455/1455 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - accuracy: 0.3872 - loss: 2.6821 - val_accuracy: 0.4747 - val_loss: 2.3287
# Точность на фолде 3: 47.47%
# Обучение на фолде 4/5
# Epoch 1/10
# 1455/1455 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.0372 - loss: 4.0411 - val_accuracy: 0.0491 - val_loss: 3.7523
# Epoch 2/10
# 1455/1455 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.0631 - loss: 3.7621 - val_accuracy: 0.2341 - val_loss: 3.6332
# Epoch 3/10
# 1455/1455 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.0866 - loss: 3.6852 - val_accuracy: 0.2853 - val_loss: 3.5457
# Epoch 4/10
# 1455/1455 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.1263 - loss: 3.5966 - val_accuracy: 0.3369 - val_loss: 3.4359
# Epoch 5/10
# 1455/1455 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.1772 - loss: 3.4949 - val_accuracy: 0.3747 - val_loss: 3.2862
# Epoch 6/10
# 1455/1455 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.2393 - loss: 3.3425 - val_accuracy: 0.4019 - val_loss: 3.0897
# Epoch 7/10
# 1455/1455 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.3002 - loss: 3.1607 - val_accuracy: 0.4231 - val_loss: 2.8595
# Epoch 8/10
# 1455/1455 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.3461 - loss: 2.9574 - val_accuracy: 0.4403 - val_loss: 2.6306
# Epoch 9/10
# 1455/1455 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.3823 - loss: 2.7617 - val_accuracy: 0.4624 - val_loss: 2.4289
# Epoch 10/10
# 1455/1455 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.4122 - loss: 2.5831 - val_accuracy: 0.4841 - val_loss: 2.2648
# Точность на фолде 4: 48.41%
# Обучение на фолде 5/5
# Epoch 1/10
# 1455/1455 ━━━━━━━━━━━━━━━━━━━━ 9s 5ms/step - accuracy: 0.0439 - loss: 4.0150 - val_accuracy: 0.0648 - val_loss: 3.6963
# Epoch 2/10
# 1455/1455 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.0808 - loss: 3.7292 - val_accuracy: 0.2394 - val_loss: 3.5447
# Epoch 3/10
# 1455/1455 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.1198 - loss: 3.6153 - val_accuracy: 0.3328 - val_loss: 3.4041
# Epoch 4/10
# 1455/1455 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.1750 - loss: 3.4866 - val_accuracy: 0.3665 - val_loss: 3.2313
# Epoch 5/10
# 1455/1455 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.2328 - loss: 3.3211 - val_accuracy: 0.3986 - val_loss: 3.0254
# Epoch 6/10
# 1455/1455 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.2868 - loss: 3.1420 - val_accuracy: 0.4207 - val_loss: 2.7991
# Epoch 7/10
# 1455/1455 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.3316 - loss: 2.9433 - val_accuracy: 0.4391 - val_loss: 2.5788
# Epoch 8/10
# 1455/1455 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.3697 - loss: 2.7630 - val_accuracy: 0.4600 - val_loss: 2.3939
# Epoch 9/10
# 1455/1455 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.3961 - loss: 2.6067 - val_accuracy: 0.4776 - val_loss: 2.2470
# Epoch 10/10
# 1455/1455 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.4160 - loss: 2.4849 - val_accuracy: 0.4965 - val_loss: 2.1273
# Точность на фолде 5: 49.65%
# Средняя точность по 5 фолдам: 49.08%

# %%
# Построение графика точности на каждом фолде
plt.figure(figsize=(8, 6))
folds = np.arange(1, len(fold_accuracies) + 1)

# Вывод точности для каждого фолда
plt.plot(folds, np.array(fold_accuracies) * 100, marker='o', linestyle='-', color='b', label='Точность на фолде')

# Вывод средней точности
plt.axhline(y=np.mean(fold_accuracies) * 100, color='r', linestyle='--', label=f'Средняя точность ({np.mean(fold_accuracies) * 100:.2f}%)')

# Настройка подписей
plt.title('Точность на каждом фолде кросс-валидации')
plt.xlabel('Номер фолда')
plt.ylabel('Точность (%)')
plt.xticks(folds)
plt.legend(loc='lower right')
plt.grid(True)

# Отображение графика
plt.show()

# %%
def recognize_text(image_file):
    # Извлекаем буквы с изображения
    letters = letters_extract(image_file)

    recognized_text = []

    # Пройдем по каждому фрагменту с буквой
    for _, _, letter in letters:
        # Преобразуем букву в формат, который принимает модель
        letter = letter.reshape(1, 28, 28, 1).astype('float32') / 255.0

        # Предсказываем класс с помощью обученной модели
        prediction = model.predict(letter)
        
        # Определяем индекс класса с наибольшей вероятностью
        predicted_label_index = np.argmax(prediction)

        # Получаем символ, используя наш словарь emnist_labels
        recognized_char = emnist_labels[predicted_label_index]
        recognized_text.append(recognized_char)

    # Соединяем буквы в строку и возвращаем результат
    return ''.join(recognized_text)

display(Image.fromarray(cv2.imread("text-hand.png")))
result_text = recognize_text("text-hand.png")
print(f"Распознанный текст: {result_text}")
# Out:
# <PIL.Image.Image image mode=RGB size=860x227>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 147ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# Распознанный текст: h8110W0r1d
